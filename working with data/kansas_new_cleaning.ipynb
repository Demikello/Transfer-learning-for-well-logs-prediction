# %%
# !pip install welly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 647.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import welly.quality as wq
from IPython.display import HTML, display
import welly

# %%
df = pd.read_csv('KansaS_.csv')

# %%
df = df.set_index(['UWI', 'DEPT'])

# %%
df.head()
# Out:
#                     CALI  RHOB  DRHO       GR  NPHI        SP
# UWI          DEPT
# 15-007-23675 690.0   NaN   NaN   NaN  70.7249   NaN  113.3384
#              690.5   NaN   NaN   NaN  65.8621   NaN  113.2592
#              691.0   NaN   NaN   NaN  62.5701   NaN  113.1442
#              691.5   NaN   NaN   NaN  65.0876   NaN  113.0549
#              692.0   NaN   NaN   NaN  69.1327   NaN  113.0585

# %%
df.shape
# Out:
# (792376, 6)

# %%
df_reset = df.reset_index()

df_unique = df_reset.drop_duplicates()

df = df_unique.set_index(['UWI', 'DEPT'])

# %%
df = df.rename(index={15189226790000: '15189226780000'})

# %%
# Расчет частот каротажей в скважинах без поностью пропущенных значений
count_logs = {}
for well in df.index.get_level_values(0).unique():
  for colum in df.columns:
    if df.loc[well][colum].notnull().any() == True:
      if colum in count_logs:
            count_logs[colum] += 1
      else:
            count_logs[colum] = 1
result_dict = {key: value / 94 for key, value in count_logs.items()}
dict(sorted(result_dict.items(), key = lambda x: x[1], reverse = True))
# Out:
# {'CALI': 0.9893617021276596,
#  'RHOB': 0.9893617021276596,
#  'DRHO': 0.9893617021276596,
#  'GR': 0.9893617021276596,
#  'NPHI': 0.9893617021276596,
#  'SP': 0.9787234042553191}

# %%
df_test = df.copy()

# %%
def values_nan(df, dept_1, dept_2, well):
    depth_mask = (df.index.get_level_values(1) < dept_1) | (df.index.get_level_values(1) > dept_2)
    mask = (df.index.get_level_values(0) == well) & depth_mask
    df = df[~mask | (df.index.get_level_values(0) != well)]
    return df

# %%
nan_list = [{'dept_1': 1648.0, 'dept_2': 5504.0, 'well': '15-007-20640-00-01'},
            {'dept_1': 1438.0, 'dept_2': 5310.0, 'well': '15-007-23592'},
            {'dept_1': 1544.0, 'dept_2': 5321.5, 'well': '15-007-23599'},
            {'dept_1': 1690.0, 'dept_2': 5502.0, 'well': '15-007-23605'},
            {'dept_1': 3238.0, 'dept_2': 4781.5, 'well': '15-007-23648'},
            {'dept_1': 3150.0, 'dept_2': 4791.0, 'well': '15-007-23650'},
            {'dept_1': 3048.0, 'dept_2': 4643.0, 'well': '15-007-23674'},
            {'dept_1': 3196.0, 'dept_2': 4736.0, 'well': '15-007-23675'},
            {'dept_1': 3150.0, 'dept_2': 4809.0, 'well': '15-007-23684'},
            {'dept_1': 3550.0, 'dept_2': 5903.5, 'well': '15-007-23685'},
            {'dept_1': 3498.0, 'dept_2': 4935.0, 'well': '15-007-23711'},
            {'dept_1': 3090.0, 'dept_2': 5033.0, 'well': '15-007-23779'},
            {'dept_1': 3398.0, 'dept_2': 4926.0, 'well': '15-007-23815-00-00'},
            {'dept_1': 3398.0, 'dept_2': 4793.5, 'well': '15-007-23869'},
            {'dept_1': 205.5, 'dept_2': 5689.5, 'well': '15-007-23917-00-00'},
            {'dept_1': 3200.0, 'dept_2': 5182.0, 'well': '15-007-23960-00-00'},
            {'dept_1': 3700.0, 'dept_2': 5248.5, 'well': '15-007-24032'},
            {'dept_1': 3300.0, 'dept_2': 4823.5, 'well': '15-007-24089'},
            {'dept_1': 3600.0, 'dept_2': 5592.0, 'well': '15-007-24092-00-00'},
            {'dept_1': 3795.0, 'dept_2': 5507.5, 'well': '15-007-24125-00-00'},
            {'dept_1': 3550.0, 'dept_2': 5509.5, 'well': '15-007-24127-00-00'},
            {'dept_1': 3740.5, 'dept_2': 5053.0, 'well': '15-007-24327-00'},
            {'dept_1': 3728.0, 'dept_2': 5060.0, 'well': '15-023-21217'},
            {'dept_1': 4090.0, 'dept_2': 5471.5, 'well': '15-025-21610-00-00'},
            {'dept_1': 3538.0, 'dept_2': 4800.5, 'well': '15-055-22076'},
            {'dept_1': 1928.0, 'dept_2': 5035.5, 'well': '15-055-22099-00-00'},
            {'dept_1': 1824.0, 'dept_2': 5006.5, 'well': '15-055-22131'},
            {'dept_1': 3740.0, 'dept_2': 4933.5, 'well': '15-055-22132'},
            {'dept_1': 3700.0, 'dept_2': 4555.0, 'well': '15-055-22134'},
            {'dept_1': 3490.0, 'dept_2': 4824.5, 'well': '15-055-22137'},
            {'dept_1': 3700.0, 'dept_2': 4757.5, 'well': '15-055-22149'},
            {'dept_1': 3698.0, 'dept_2': 4813.0, 'well': '15-055-22151'},
            {'dept_1': 3700.0, 'dept_2': 4809.0, 'well': '15-055-22160'},
            {'dept_1': 3700.0, 'dept_2': 4813.0, 'well': '15-055-22161'},
            {'dept_1': 1819.5, 'dept_2': 4968.5, 'well': '15-055-22166'},
            {'dept_1': 3696.0, 'dept_2': 4820.5, 'well': '15-055-22171'},
            {'dept_1': 1807.0, 'dept_2': 4919.5, 'well': '15-055-22172'},
            {'dept_1': 3650.0, 'dept_2': 4818.5, 'well': '15-055-22173'},
            {'dept_1': 3700.0, 'dept_2': 4885.0, 'well': '15-055-22271'},
            {'dept_1': 3600.0, 'dept_2': 4875.5, 'well': '15-055-22320-00-00'},
            {'dept_1': 3600.0, 'dept_2': 4858.0, 'well': '15-055-22334-00-00'},
            {'dept_1': 2495.0, 'dept_2': 4903.5, 'well': '15-055-22359-00-00'},
            {'dept_1': 3598.0, 'dept_2': 4896.0, 'well': '15-055-22379-00-00'},
            {'dept_1': 2198.0, 'dept_2': 4864.0, 'well': '15-055-22443-00-00'},
            {'dept_1': 1827.0, 'dept_2': 4865.0, 'well': '15-055-224444-00-00'},
            {'dept_1': 2198.0, 'dept_2': 4864.5, 'well': '15-055-22445-00-00'},
            {'dept_1': 2198.0, 'dept_2': 4805.5, 'well': '15-055-22446-00-00'},
            {'dept_1': 2502.5, 'dept_2': 4934.0, 'well': '15-055-22466-00-00'},
            {'dept_1': 1785.0, 'dept_2': 4848.5, 'well': '15-055-22503-00-00'},
            {'dept_1': 3645.0, 'dept_2': 4800.5, 'well': '15-055-22509-00-00'},
            {'dept_1': 3895.0, 'dept_2': 4823.5, 'well': '15-055-22527-00-00'},
            {'dept_1': 3158.0, 'dept_2': 4693.5, 'well': '15-077-23705'},
            {'dept_1': 2279.0, 'dept_2': 5023.0, 'well': '15-093-21895-00-00'},
            {'dept_1': 2196.0, 'dept_2': 5044.5, 'well': '15-093-21896'},
            {'dept_1': 1962.0, 'dept_2': 5007.0, 'well': '15-093-21973-00-00'},
            {'dept_1': 3700.0, 'dept_2': 4947.0, 'well': '15-093-21989-00-00'},
            {'dept_1': 1804.0, 'dept_2': 5654.5, 'well': '15-175-21301'},
            {'dept_1': 1679.0, 'dept_2': 5810.0, 'well': '15-175-22203-00-00'},
            {'dept_1': 1709.0, 'dept_2': 5362.5, 'well': '15-175-22246-00-00'},
            {'dept_1': 1583.0, 'dept_2': 6334.5, 'well': '15-175-22267-00-00'},
            {'dept_1': 350.0, 'dept_2': 5918.5, 'well': '15-181-20636'},
            {'dept_1': 2498.0, 'dept_2': 6413.5, 'well': '15-189-22677'},
            {'dept_1': 2458.0, 'dept_2': 6619.0, 'well': '15-189-22681'},
            {'dept_1': 2498.0, 'dept_2': 6391.0, 'well': '15-189-22682'},
            {'dept_1': 2493.0, 'dept_2': 6875.5, 'well': '15-189-226860000'},
            {'dept_1': 2428.0, 'dept_2': 6505.0, 'well': '15-189-22694-0000'},
            {'dept_1': 1713.5, 'dept_2': 6495.5, 'well': '15-189-22757'},
            {'dept_1': 1772.5, 'dept_2': 7677.0, 'well': '15-189-22781'},
            {'dept_1': 1803.0, 'dept_2': 6737.0, 'well': '15-189-22845-00-00'},
            {'dept_1': 1529.0, 'dept_2': 6154.5, 'well': '15-189-22858-01-00'},
            {'dept_1': 1740.5, 'dept_2': 5691.0, 'well': '15-189-22860-00-00'},
            {'dept_1': 4250.0, 'dept_2': 5749.0, 'well': '15033215890000'},
            {'dept_1': 3690.0, 'dept_2': 4821.5, 'well': '15055221240000'},
            {'dept_1': 3796.0, 'dept_2': 4910.5, 'well': '15055221390000'},
            {'dept_1': 3700.0, 'dept_2': 4945.5, 'well': '15055221500000'},
            {'dept_1': 4000.0, 'dept_2': 4921.5, 'well': '15055222140000'},
            {'dept_1': 3700.0, 'dept_2': 4695.0, 'well': '15055222310000'},
            {'dept_1': 3695.0, 'dept_2': 4927.0, 'well': '15055225010000'},
            {'dept_1': 3700.0, 'dept_2': 4783.5, 'well': '15093218840000'},
            {'dept_1': 3845.0, 'dept_2': 4875.0, 'well': '15093218850000'},
            {'dept_1': 1786.5, 'dept_2': 5078.5, 'well': '15093219190000'},
            {'dept_1': 3695.0, 'dept_2': 4942.0, 'well': '15093219770100'},
            {'dept_1': 3400.0, 'dept_2': 4990.0, 'well': '15093219950000'},
            {'dept_1': 2352.0, 'dept_2': 5640.5, 'well': '15175221770000'},
            {'dept_1': 2479.0, 'dept_2': 6236.0, 'well': '15189226750000'},
            {'dept_1': 3388.5, 'dept_2': 6295.0, 'well': '15189226780000'},
            {'dept_1': 2383.0, 'dept_2': 3388.0, 'well': '15189226790000'},
            {'dept_1': 2448.0, 'dept_2': 6394.5, 'well': '15189226830000'},
            {'dept_1': 1777.0, 'dept_2': 6162.0, 'well': '15189226850000-W'},
            {'dept_1': 1701.0, 'dept_2': 6281.0, 'well': '15189227150000-S'},
            {'dept_1': 2448.0, 'dept_2': 6595.0, 'well': '15189227280000'},
            {'dept_1': 2418.0, 'dept_2': 6119.0, 'well': '15189227510000'},
            {'dept_1': 3700.0, 'dept_2': 4834.0, 'well': '22-23S-34W'}
]

# %%
for params in nan_list:
    df_test = values_nan(df_test, **params)

# %%
wells = []
for well in nan_list:
    wells.append(well['well'])

# %%
df_new = df_test.loc[wells]

# %%
neut_proc = ['15-189-22677', '15-189-22682', '15-189-22757']
mask = df_new.index.get_level_values(0).isin(neut_proc)
df_new.loc[mask, 'NPHI'] = df_new.loc[mask, 'NPHI'] / 100

# %%
def correction_outlier(df, depth1, depth2, well, curve, value, inequality='>'):
    depth_mask = (df.index.get_level_values(1) >= depth1) & (df.index.get_level_values(1) <= depth2)
    mask = (df.index.get_level_values(0) == well) & depth_mask
    df.loc[mask, curve] = df.loc[mask, curve].fillna(0)
    if inequality == '>':
        df.loc[mask, curve] = df.loc[mask, curve].mask(df.loc[mask, curve] > value)
    elif inequality == '<':
        df.loc[mask, curve] = df.loc[mask, curve].mask(df.loc[mask, curve] < value)
    df.loc[mask, curve] = df.loc[mask, curve].interpolate(method='linear')
    df.loc[mask, curve] = df.loc[mask, curve].replace(0, np.nan)

# %%
corrections_outlier_list = [{'depth1': 1650, 'depth2': 5400, 'well': '15-007-20640-00-01', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1650, 'depth2': 5400, 'well': '15-007-20640-00-01', 'curve': 'CALI', 'value': 20, 'inequality': '>'},
                            {'depth1': 1440, 'depth2': 5300, 'well': '15-007-23592', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1440, 'depth2': 5300, 'well': '15-007-23592', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 1600, 'depth2': 5300, 'well': '15-007-23599', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 1550, 'depth2': 5300, 'well': '15-007-23599', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1695, 'depth2': 5400, 'well': '15-007-23605', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1695, 'depth2': 5000, 'well': '15-007-23605', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23648', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4000, 'depth2': 4600, 'well': '15-007-23648', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23650', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23674', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23675', 'curve': 'GR', 'value': 480, 'inequality': '>'},
                            {'depth1': 3200, 'depth2': 4600, 'well': '15-007-23675', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23684', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 3200, 'depth2': 4800, 'well': '15-007-23684', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4000, 'depth2': 5000, 'well': '15-007-23685', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4000, 'depth2': 5500, 'well': '15-007-23685', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4000, 'depth2': 4800, 'well': '15-007-23711', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4750, 'well': '15-007-23779', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4750, 'well': '15-007-23779', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23815-00-00', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23869', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 1000, 'depth2': 5300, 'well': '15-007-23917-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4000, 'depth2': 5300, 'well': '15-007-23917-00-00', 'curve': 'GR', 'value': 490, 'inequality': '>'},
                            {'depth1': 4000, 'depth2': 5000, 'well': '15-007-23960-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-23960-00-00', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 3800, 'depth2': 5000, 'well': '15-007-24032', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-24032', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-24089', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-24089', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 5500, 'well': '15-007-24092-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-24092-00-00', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-24125-00-00', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4600, 'well': '15-007-24125-00-00', 'curve': 'CALI', 'value': 9, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 5400, 'well': '15-007-24125-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4700, 'well': '15-007-24127-00-00', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 3800, 'depth2': 5500, 'well': '15-007-24127-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4600, 'depth2': 4800, 'well': '15-007-24327-00', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 4200, 'depth2': 4400, 'well': '15-023-21217', 'curve': 'CALI', 'value': 10, 'inequality': '>'},
                            {'depth1': 3600, 'depth2': 4800, 'well': '15-055-22076', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1930, 'depth2': 5000, 'well': '15-055-22099-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1930, 'depth2': 5000, 'well': '15-055-22099-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1830, 'depth2': 5000, 'well': '15-055-22131', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3800, 'depth2': 4930, 'well': '15-055-22132', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3500, 'depth2': 4820, 'well': '15-055-22137', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3800, 'depth2': 4750, 'well': '15-055-22149', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3800, 'depth2': 4750, 'well': '15-055-22149', 'curve': 'CALI', 'value': 10.5, 'inequality': '>'},
                            {'depth1': 4600, 'depth2': 4800, 'well': '15-055-22160', 'curve': 'CALI', 'value': 7, 'inequality': '<'},
                            {'depth1': 1830, 'depth2': 4960, 'well': '15-055-22166', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1810, 'depth2': 4910, 'well': '15-055-22172', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3650, 'depth2': 4810, 'well': '15-055-22173', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3610, 'depth2': 4860, 'well': '15-055-22320-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 4900, 'well': '15-055-22359-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3600, 'depth2': 4890, 'well': '15-055-22379-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1830, 'depth2': 4860, 'well': '15-055-224444-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2200, 'depth2': 4800, 'well': '15-055-22446-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1800, 'depth2': 4840, 'well': '15-055-22503-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3650, 'depth2': 4790, 'well': '15-055-22509-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4610, 'well': '15-077-23705', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 2280, 'depth2': 5020, 'well': '15-093-21895-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2197, 'depth2': 5040, 'well': '15-093-21896', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1970, 'depth2': 5000, 'well': '15-093-21973-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1810, 'depth2': 5630, 'well': '15-175-21301', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1680, 'depth2': 5803, 'well': '15-175-22203-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1710, 'depth2': 5360, 'well': '15-175-22246-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1590, 'depth2': 6330, 'well': '15-175-22267-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4000, 'depth2': 5200, 'well': '15-181-20636', 'curve': 'GR', 'value': 500, 'inequality': '>'},
                            {'depth1': 2460, 'depth2': 6618, 'well': '15-189-22681', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 6870, 'well': '15-189-226860000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2430, 'depth2': 6500, 'well': '15-189-22694-0000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2430, 'depth2': 6500, 'well': '15-189-22694-0000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 4000, 'well': '15-189-22781', 'curve': 'CALI', 'value': 15, 'inequality': '>'},
                            {'depth1': 1777, 'depth2': 7670, 'well': '15-189-22781', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1810, 'depth2': 6730, 'well': '15-189-22845-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1535, 'depth2': 6150, 'well': '15-189-22858-01-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1745, 'depth2': 5690, 'well': '15-189-22860-00-00', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 4400, 'depth2': 5740, 'well': '15033215890000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3695, 'depth2': 4820, 'well': '15055221240000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 3705, 'depth2': 4940, 'well': '15055221500000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1790, 'depth2': 5070, 'well': '15093219190000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2355, 'depth2': 5635, 'well': '15175221770000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2480, 'depth2': 6230, 'well': '15189226750000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2385, 'depth2': 3385, 'well': '15189226790000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 6000, 'depth2': 6300, 'well': '15189226830000', 'curve': 'CALI', 'value': 14, 'inequality': '>'},
                            {'depth1': 2450, 'depth2': 6390, 'well': '15189226830000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1780, 'depth2': 6160, 'well': '15189226850000-W', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1705, 'depth2': 6280, 'well': '15189227150000-S', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2450, 'depth2': 6590, 'well': '15189227280000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2420, 'depth2': 6115, 'well': '15189227510000', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 6411, 'well': '15-189-22677', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 6390, 'well': '15-189-22682', 'curve': 'NPHI', 'value': 0, 'inequality': '<'},
                            {'depth1': 1715, 'depth2': 6490, 'well': '15-189-22757', 'curve': 'NPHI', 'value': 0, 'inequality': '<'}
]

# %%
for params in corrections_outlier_list:
    correction_outlier(df_new, **params)

# %%
def interpolate_nan_values(group):
    for column in group.columns:
        series = group[column]

        # Find sequences of NaN values
        nan_sequences = []
        current_sequence = []
        for i in range(len(series)):
            if pd.isnull(series.iloc[i]):
                current_sequence.append(i)
            elif current_sequence:
                nan_sequences.append(current_sequence)
                current_sequence = []
        if current_sequence:
            nan_sequences.append(current_sequence)

        # Interpolate sequences of NaN values if they do not exceed 100
        for sequence in nan_sequences:
            if len(sequence) <= 100:
                # Interpolate the sequence with the upper and lower numerical values
                upper_value = series.iloc[sequence[0]-1] if sequence[0] > 0 else series.iloc[sequence[0]]
                lower_value = series.iloc[sequence[-1]+1] if sequence[-1] < len(series) - 1 else series.iloc[sequence[-1]]
                series.iloc[sequence] = np.interp(sequence, [sequence[0], sequence[-1]], [upper_value, lower_value])

        group[column] = series

    return group

df_depth_filtered = df_new.groupby(level=0).apply(interpolate_nan_values).droplevel(0)

# %%
tests = {'GR': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_positive],
         'RHOB': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_positive],
         'NPHI': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_between(0,1)],
         'DRHO': [wq.no_flat,
                  wq.no_gaps],
         'CALI': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_positive],
         'SP': [wq.no_flat,
                  wq.no_gaps],
         }

# %%
for well in df_depth_filtered.index.get_level_values(0).unique():
  w = df_depth_filtered.loc[well]
  wl = welly.Well({})
  for log in tests.keys():  # Проходим по логам, для которых есть тесты
        if log in w.columns:  # Проверяем, имеются ли данные по этому логe
            wl.data[log] = welly.Curve(w[log].values, basis=w.index.get_level_values('DEPT').values, mnemonic=log)

 # show test results in HTML table
  print('\n', '\n')
  print('WELL NAME: ' + well)
  print('CURVE QUALITY SUMMARY')
  html = wl.qc_table_html(tests)
  display(HTML(html, metadata = {'title': well,}))
# Out:
#
#
# WELL NAME: 15-007-20640-00-01
# CURVE QUALITY SUMMARY
# <ipython-input-87-d06fd4e801b2>:8: DeprecationWarning: In a future release, the basis argument will be removed; use index instead.
#   wl.data[log] = welly.Curve(w[log].values, basis=w.index.get_level_values('DEPT').values, mnemonic=log)
# ...

# %%
df_plot = df_depth_filtered.copy()
df_plot.reset_index(inplace=True)

# %%
def create_plot(wellname, dataframe,
                curves_to_plot, depth_curve,
                log_curves=[]):

    # Count the number of tracks we need
    num_tracks = len(curves_to_plot)

    # Setup the figure and axes
    fig, ax = plt.subplots(nrows=1, ncols=num_tracks, figsize=(num_tracks*2, 10))

    # Create a super title for the entire plot
    fig.suptitle(wellname, fontsize=20, y=1.05)

    # Loop through each curve in curves_to_plot and create a track with that data
    for i, curve in enumerate(curves_to_plot):


        ax[i].plot(dataframe[curve], depth_curve)

        # Setup a few plot cosmetics
        ax[i].set_title(curve, fontsize=14, fontweight='bold')
        ax[i].grid(which='major', color='lightgrey', linestyle='-')

        # We want to pass in the deepest depth first, so we are displaying the data
        # from shallow to deep
        ax[i].set_ylim(depth_curve.max(), depth_curve.min())

        # Only set the y-label for the first track. Hide it for the rest
        if i == 0:
            ax[i].set_ylabel('DEPTH (m)', fontsize=18, fontweight='bold')
        else:
            plt.setp(ax[i].get_yticklabels(), visible = False)

        # Check to see if we have any logarithmic scaled curves
        if curve in log_curves:
            ax[i].set_xscale('log')
            ax[i].grid(which='minor', color='lightgrey', linestyle='-')

    plt.tight_layout()
    plt.show()

# %%
grouped = df_plot.groupby('UWI')
dfs_wells = []
wellnames = []

# %%
for well, data in grouped:
  dfs_wells.append(data)
  wellnames.append(well)
curves_to_plot = ['CALI', 'RHOB', 'DRHO', 'GR', 'NPHI', 'SP']

# %%
for well in range(len(wellnames)):
  create_plot(wellnames[well], dfs_wells[well],
              curves_to_plot, dfs_wells[well]['DEPT'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df_depth_filtered.to_csv('kansas_logs.csv', index = True)

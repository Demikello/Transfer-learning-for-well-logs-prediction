# %%
# !pip install welly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
from welly import Project
import pandas as pd
import numpy as np
from IPython.display import HTML, display
import welly
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')

# %%
wells = Project.from_las('/content/drive/MyDrive/FORCE_2020/*.las')
# Out:
# 223it [01:29,  2.50it/s]

# %%
df = wells.df()
# Out:
# /usr/local/lib/python3.11/dist-packages/welly/curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# /usr/local/lib/python3.11/dist-packages/welly/curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# /usr/local/lib/python3.11/dist-packages/welly/curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# /usr/local/lib/python3.11/dist-packages/welly/curve.py:470: FutureWarning: Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#   if self.df.index.is_numeric() and not self.df.index.empty:
# ...

# %%
df.head()
# Out:
#                       LITHOLOGY_GEOLINK           CALI          DRHO  NPHI  \
# UWI     DEPT
# 15/9-12 493.49313354                NaN  19.4060001370 -0.7080000040   NaN
#         494.49313354                NaN  19.4689998630 -0.7209845809   NaN
#         495.49313354                NaN  19.4060001370 -0.7985727057   NaN
#         496.49313354                NaN  19.4279205579 -0.8251035390   NaN
#         497.49313354                NaN  19.5160007480 -0.8234933996   NaN
#
#                               RHOB             GR             DTC  \
# UWI     DEPT
# 15/9-12 493.49313354  1.7890000343  64.4974823000  167.5821533200
#         494.49313354  1.5400968981  62.0278265476  167.5418618006
#         495.49313354  1.3674537056  62.5387849878  166.4518538221
#         496.49313354  1.3567709103  69.5576980261  172.2892111358
#         497.49313354  1.1935066201  63.2170654585  167.3084858830
#
#                                    DTE          RDEP            SP  ...  BS  \
# ...

# %%
# Расчет частот каротажей в скважинах без поностью пропущенных значений
count_logs = {}
for well in df.index.get_level_values(0).unique():
  for colum in df.columns:
    if df.loc[well][colum].notnull().any() == True:
      if colum in count_logs:
            count_logs[colum] += 1
      else:
            count_logs[colum] = 1
result_dict = {key: value / 223 for key, value in count_logs.items()}
dict(sorted(result_dict.items(), key = lambda x: x[1], reverse = True))
# Out:
# {'LITHOLOGY_GEOLINK': 0.9865470852017937,
#  'GR': 0.9192825112107623,
#  'RDEP': 0.9147982062780269,
#  'RMED': 0.8968609865470852,
#  'RHOB': 0.8923766816143498,
#  'DTC': 0.8878923766816144,
#  'CALI': 0.8789237668161435,
#  'DRHO': 0.8385650224215246,
#  'NPHI': 0.8385650224215246,
#  'RSHA': 0.6905829596412556,
#  'SP': 0.6591928251121076,
#  'BS': 0.47533632286995514,
#  'PEF': 0.4080717488789238,
#  'DTE': 0.2645739910313901,
#  'ROP': 0.23766816143497757,
#  'DTS': 0.21973094170403587,
#  'DCAL': 0.15695067264573992,
#  'THOR': 0.15246636771300448,
#  'URAN': 0.15246636771300448,
#  'RMIC': 0.15246636771300448,
#  'SGR': 0.08071748878923767,
#  'RXO': 0.06278026905829596,
#  'MUDWEIGHT': 0.06278026905829596,
#  'DT': 0.03139013452914798,
#  'RHOM': 0.017937219730941704,
#  'CGR': 0.004484304932735426,
#  'TGAS': 0.004484304932735426}

# %%
df = df[['CALI', 'RHOB', 'DRHO', 'GR', 'NPHI', 'SP']]

# %%
# Отбор скважин, в которых каротажи не имеют полностью пропущенных значений
for well in df.index.get_level_values(0).unique():
    for colum in df.columns:
      if df.loc[well][colum].notnull().any() != True:
        df = df.drop(index = well, level = 'UWI')
        break

# %%
df.head()
# Out:
#                                CALI          RHOB          DRHO  \
# UWI     DEPT
# 15/9-12 493.49313354  19.4060001370  1.7890000343 -0.7080000040
#         494.49313354  19.4689998630  1.5400968981 -0.7209845809
#         495.49313354  19.4060001370  1.3674537056 -0.7985727057
#         496.49313354  19.4279205579  1.3567709103 -0.8251035390
#         497.49313354  19.5160007480  1.1935066201 -0.8234933996
#
#                                  GR  NPHI            SP
# UWI     DEPT
# 15/9-12 493.49313354  64.4974823000   NaN  0.6946996450
#         494.49313354  62.0278265476   NaN -1.3039315634
#         495.49313354  62.5387849878   NaN  1.9761374373
#         496.49313354  69.5576980261   NaN  1.3657328922
#         497.49313354  63.2170654585   NaN -0.4309031066

# %%
df_test = df.copy()

# %%
def values_nan(df, dept_1, dept_2, well):
    depth_mask = (df.index.get_level_values(1) < dept_1) | (df.index.get_level_values(1) > dept_2)
    mask = (df.index.get_level_values(0) == well) & depth_mask
    df = df[~mask | (df.index.get_level_values(0) != well)]
    return df

# %%
nan_list = [{'dept_1': 1096.49313354, 'dept_2': 3744.49313354, 'well': '15/9-12'},
            {'dept_1': 1139.08810425, 'dept_2': 3275.08810425, 'well': '15/9-13'},
            {'dept_1': 501.37210083, 'dept_2': 3564.37210083, 'well': '15/9-14'},
            {'dept_1': 1151.02883911, 'dept_2': 3200.02883911, 'well': '15/9-15'},
            {'dept_1': 1122.33206177, 'dept_2': 3114.33206177, 'well': '15/9-17'},
            {'dept_1': 1150.0, 'dept_2': 3611.0, 'well': '15/9-18'},
            {'dept_1': 2818.1080322, 'dept_2': 3699.1080322, 'well': '15/9-5'},
            {'dept_1': 2723.48303223, 'dept_2': 3785.48303223, 'well': '15/9-7'},
            {'dept_1': 2791.12991333, 'dept_2': 3722.12991333, 'well': '15/9-8'},
            {'dept_1': 1129.34408569, 'dept_2': 3040.34408569, 'well': '15/9-9'},
            {'dept_1': 2664.2697754, 'dept_2': 2923.2697754, 'well': '16/1-2'},
            {'dept_1': 1414.1131897, 'dept_2': 3123.1131897, 'well': '16/10-1'},
            {'dept_1': 2776.8217773, 'dept_2': 3136.8217773, 'well': '16/10-2'},
            {'dept_1': 763.76629639, 'dept_2': 2899.76629639, 'well': '16/4-1'},
            {'dept_1': 1201.375007629, 'dept_2': 3129.375007629, 'well': '16/7-2'},
            {'dept_1': 2286.125, 'dept_2': 3132.125, 'well': '16/7-3'},
            {'dept_1': 1279.5, 'dept_2': 2785.5, 'well': '16/7-4'},
            {'dept_1': 1262.31985474, 'dept_2': 2889.31985474, 'well': '16/7-5'},
            {'dept_1': 1155.8436279, 'dept_2': 2698.8436279, 'well': '16/7-6'},
            {'dept_1': 1550.1209717, 'dept_2': 2307.1209717, 'well': '16/8-1'},
            {'dept_1': 2101.1361084, 'dept_2': 2857.1361084, 'well': '17/4-1'},
            {'dept_1': 1280.12496948, 'dept_2': 2543.12496948, 'well': '25/10-4 R'},
            {'dept_1': 1275.6159668, 'dept_2': 1999.6159668, 'well': '25/11-15'},
            {'dept_1': 1399.59057617, 'dept_2': 2164.59057617, 'well': '25/11-5'},
            {'dept_1': 3296.62524414, 'dept_2': 3895.62524414, 'well': '25/2-13 T4'},
            {'dept_1': 3022.6790771, 'dept_2': 3618.6790771, 'well': '25/2-14'},
            {'dept_1': 2189.55102539, 'dept_2': 4075.55102539, 'well': '25/2-7'},
            {'dept_1': 2994.74005127, 'dept_2': 3916.74005127, 'well': '25/3-1'},
            {'dept_1': 1917.3216553, 'dept_2': 2635.3216553, 'well': '25/4-1'},
            {'dept_1': 2906.16107178, 'dept_2': 3423.16107178, 'well': '25/5-1'},
            {'dept_1': 2352.657959, 'dept_2': 2874.657959, 'well': '25/5-3'},
            {'dept_1': 2792.6253662, 'dept_2': 3174.6253662, 'well': '25/5-4'},
            {'dept_1': 2180.75, 'dept_2': 2853.75, 'well': '25/6-1'},
            {'dept_1': 2031.4147949, 'dept_2': 2368.4147949, 'well': '25/6-2'},
            {'dept_1': 3919.4276123, 'dept_2': 4844.4276123, 'well': '25/7-2'},
            {'dept_1': 1174.515625, 'dept_2': 2222.515625, 'well': '25/8-5 S'},
            {'dept_1': 1993.0967, 'dept_2': 2343.0967, 'well': '25/8-7'},
            {'dept_1': 1675.82189941, 'dept_2': 3677.82189941, 'well': '26/4-1'},
            {'dept_1': 250.72601318, 'dept_2': 3794.72601318, 'well': '30/11-3'},
            {'dept_1': 1020.1519928, 'dept_2': 4229.1519928, 'well': '30/2-1'},
            {'dept_1': 2251.19400024, 'dept_2': 3562.19400024, 'well': '30/3-2 R'},
            {'dept_1': 2821.91401672, 'dept_2': 3403.91401672, 'well': '30/3-3'},
            {'dept_1': 1568.75, 'dept_2': 3277.75, 'well': '30/3-4 R'},
            {'dept_1': 3719.1010742, 'dept_2': 4767.1010742, 'well': '30/4-2'},
            {'dept_1': 2090.25012207, 'dept_2': 3993.25012207, 'well': '30/6-11'},
            {'dept_1': 1628.07043457, 'dept_2': 2894.07043457, 'well': '30/6-14'},
            {'dept_1': 950.60998535, 'dept_2': 3547.60998535, 'well': '30/6-5'},
            {'dept_1': 940.99749756, 'dept_2': 3603.99749756, 'well': '30/6-8'},
            {'dept_1': 3876.40203857, 'dept_2': 5048.40203857, 'well': '30/7-7'},
            {'dept_1': 830.05941772, 'dept_2': 2432.05941772, 'well': '31/2-1'},
            {'dept_1': 475.17501831, 'dept_2': 1828.17501831, 'well': '31/2-10'},
            {'dept_1': 1310.8798828, 'dept_2': 3034.8798828, 'well': '31/2-19 S'},
            {'dept_1': 421.08499146, 'dept_2': 2596.08499146, 'well': '31/2-2 R'},
            {'dept_1': 452.86209106, 'dept_2': 2589.86209106, 'well': '31/2-3'},
            {'dept_1': 442.56304932, 'dept_2': 1655.56304932, 'well': '31/2-7'},
            {'dept_1': 467.54394531, 'dept_2': 3378.54394531, 'well': '31/2-8'},
            {'dept_1': 453.33587646, 'dept_2': 1765.33587646, 'well': '31/2-9'},
            {'dept_1': 1286.62512207, 'dept_2': 2359.62512207, 'well': '31/3-1'},
            {'dept_1': 452.43811035, 'dept_2': 1482.43811035, 'well': '31/3-2'},
            {'dept_1': 804.37487793, 'dept_2': 2562.37487793, 'well': '31/3-3'},
            {'dept_1': 1983.03363037, 'dept_2': 2306.03363037, 'well': '31/4-10'},
            {'dept_1': 1691.2109375, 'dept_2': 2888.2109375, 'well': '31/4-2'},
            {'dept_1': 1913.0380249, 'dept_2': 4981.0380249, 'well': '31/4-3'},
            {'dept_1': 1864.54608154, 'dept_2': 3134.54608154, 'well': '31/4-4'},
            {'dept_1': 1954.0269165, 'dept_2': 2925.0269165, 'well': '31/4-5'},
            {'dept_1': 1839.43609619, 'dept_2': 2434.43609619, 'well': '31/4-6'},
            {'dept_1': 1402.00012207, 'dept_2': 2481.00012207, 'well': '31/5-2 R'},
            {'dept_1': 425.87509155, 'dept_2': 4012.87509155, 'well': '31/6-1'},
            {'dept_1': 1401.12503052, 'dept_2': 2074.12503052, 'well': '31/6-5'},
            {'dept_1': 3903.63586426, 'dept_2': 4530.63586426, 'well': '33/5-2'},
            {'dept_1': 1961.1920166, 'dept_2': 3904.1920166, 'well': '33/6-1'},
            {'dept_1': 1498.60995483, 'dept_2': 3073.60995483, 'well': '33/9-1'},
            {'dept_1': 1856.37786865, 'dept_2': 3525.37786865, 'well': '33/9-11'},
            {'dept_1': 1787.835083, 'dept_2': 3354.835083, 'well': '33/9-6'},
            {'dept_1': 226.21697998, 'dept_2': 2793.21697998, 'well': '34/10-12'},
            {'dept_1': 1899.74101257, 'dept_2': 4031.74101257, 'well': '34/10-16 R'},
            {'dept_1': 222.75, 'dept_2': 3242.75, 'well': '34/10-17'},
            {'dept_1': 1073.00001526, 'dept_2': 2212.00001526, 'well': '34/10-19'},
            {'dept_1': 1877.578125, 'dept_2': 3995.578125, 'well': '34/10-21'},
            {'dept_1': 3836.91439819, 'dept_2': 4743.91439819, 'well': '34/10-23'},
            {'dept_1': 1751.56594849, 'dept_2': 2768.56594849, 'well': '34/10-5'},
            {'dept_1': 1684.46392822, 'dept_2': 2239.46392822, 'well': '34/10-7'},
            {'dept_1': 2013.9804688, 'dept_2': 4068.9804688, 'well': '34/2-2 R'},
            {'dept_1': 3553.60943604, 'dept_2': 4089.60943604, 'well': '34/2-4'},
            {'dept_1': 1963.1618652, 'dept_2': 3605.1618652, 'well': '34/4-2'},
            {'dept_1': 1005.78210449, 'dept_2': 4465.78210449, 'well': '34/4-3'},
            {'dept_1': 1854.37493896, 'dept_2': 2777.37493896, 'well': '34/7-12'},
            {'dept_1': 1858.5001221, 'dept_2': 2981.5001221, 'well': '34/7-13'},
            {'dept_1': 2550.47238159, 'dept_2': 3165.47238159, 'well': '34/7-20'},
            {'dept_1': 1863.87487793, 'dept_2': 3146.87487793, 'well': '34/7-5'},
            {'dept_1': 1754.97918701, 'dept_2': 3607.97918701, 'well': '34/8-1'},
            {'dept_1': 1322.0939941, 'dept_2': 3315.0939941, 'well': '34/8-3'},
            {'dept_1': 2404.388916, 'dept_2': 3921.388916, 'well': '34/8-6'},
            {'dept_1': 3950.0371094, 'dept_2': 5436.0371094, 'well': '34/8-7'},
            {'dept_1': 2014.0010376, 'dept_2': 3356.0010376, 'well': '35/11-1'},
            {'dept_1': 1151.0018311, 'dept_2': 2863.0018311, 'well': '35/11-10'},
            {'dept_1': 1254.0043945, 'dept_2': 3189.0043945, 'well': '35/11-11'},
            {'dept_1': 1002.35791016, 'dept_2': 4017.35791016, 'well': '35/11-2'},
            {'dept_1': 2681.22799683, 'dept_2': 3755.22799683, 'well': '35/11-5'},
            {'dept_1': 1989.04040527, 'dept_2': 3969.04040527, 'well': '35/11-6'},
            {'dept_1': 1772.625, 'dept_2': 2880.625, 'well': '35/11-7'},
            {'dept_1': 1252.0020752, 'dept_2': 2785.0020752, 'well': '35/11-9'},
            {'dept_1': 2200.18890381, 'dept_2': 3019.18890381, 'well': '35/12-1'},
            {'dept_1': 2286.052002, 'dept_2': 4397.052002, 'well': '35/3-2'},
            {'dept_1': 2027.15161133, 'dept_2': 4099.15161133, 'well': '35/3-5'},
            {'dept_1': 891.14508057, 'dept_2': 4341.14508057, 'well': '35/8-1'},
            {'dept_1': 1861.2490234, 'dept_2': 2852.2490234, 'well': '35/9-2'},
            {'dept_1': 1256.1519775, 'dept_2': 2126.1519775, 'well': '36/7-1'},
            {'dept_1': 1300.5, 'dept_2': 3292.5, 'well': '6/3-2'},
            {'dept_1': 2137.06079102, 'dept_2': 2802.06079102, 'well': '7/1-1'}
]

# %%
for params in nan_list:
    df_test = values_nan(df_test, **params)

# %%
wells = []
for well in nan_list:
    wells.append(well['well'])

# %%
df_new = df_test.loc[wells]

# %%
neut_proc = ['35/11-7', '35/11-6', '35/11-5', '34/8-3', '34/8-1', '25/2-13 T4']
mask = df_new.index.get_level_values(0).isin(neut_proc)
df_new.loc[mask, 'NPHI'] = df_new.loc[mask, 'NPHI'] / 100

# %%
def interpolate_nan_values(group):
    for column in group.columns:
        series = group[column]

        # Find sequences of NaN values
        nan_sequences = []
        current_sequence = []
        for i in range(len(series)):
            if pd.isnull(series.iloc[i]):
                current_sequence.append(i)
            elif current_sequence:
                nan_sequences.append(current_sequence)
                current_sequence = []
        if current_sequence:
            nan_sequences.append(current_sequence)

        # Interpolate sequences of NaN values if they do not exceed 100
        for sequence in nan_sequences:
            if len(sequence) <= 100:
                # Interpolate the sequence with the upper and lower numerical values
                upper_value = series.iloc[sequence[0]-1] if sequence[0] > 0 else series.iloc[sequence[0]]
                lower_value = series.iloc[sequence[-1]+1] if sequence[-1] < len(series) - 1 else series.iloc[sequence[-1]]
                series.iloc[sequence] = np.interp(sequence, [sequence[0], sequence[-1]], [upper_value, lower_value])

        group[column] = series

    return group

df_depth_filtered = df_new.groupby(level=0).apply(interpolate_nan_values).droplevel(0)

# %%
def correction_outlier(df, depth1, depth2, well, curve, value, inequality='>'):
    depth_mask = (df.index.get_level_values(1) >= depth1) & (df.index.get_level_values(1) <= depth2)
    mask = (df.index.get_level_values(0) == well) & depth_mask
    df.loc[mask, curve] = df.loc[mask, curve].fillna(0)
    if inequality == '>':
        df.loc[mask, curve] = df.loc[mask, curve].mask(df.loc[mask, curve] > value)
    elif inequality == '<':
        df.loc[mask, curve] = df.loc[mask, curve].mask(df.loc[mask, curve] < value)
    df.loc[mask, curve] = df.loc[mask, curve].interpolate(method='linear')
    df.loc[mask, curve] = df.loc[mask, curve].replace(0, np.nan)

# %%
corrections_outlier_list = [{'depth1': 2500, 'depth2': 3000, 'well': '15/9-13', 'curve': 'GR', 'value': 250, 'inequality': '>'},
                            {'depth1': 3000, 'depth2': 3500, 'well': '15/9-14', 'curve': 'GR', 'value': 250, 'inequality': '>'},
                            {'depth1': 2500, 'depth2': 3000, 'well': '15/9-15', 'curve': 'GR', 'value': 300, 'inequality': '>'},
                            {'depth1': 1500, 'depth2': 2000, 'well': '15/9-18', 'curve': 'DRHO', 'value': 0.5, 'inequality': '>'},
                            {'depth1': 1500, 'depth2': 2000, 'well': '15/9-18', 'curve': 'RHOB', 'value': 2.6, 'inequality': '>'},
                            {'depth1': 1129.34408569, 'depth2': 3040.34408569, 'well': '15/9-9', 'curve': 'NPHI', 'value': 0.9, 'inequality': '>'},
                            {'depth1': 2200, 'depth2': 2899.76629639, 'well': '16/4-1', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 2600, 'depth2': 2698.8436279, 'well': '16/7-6', 'curve': 'GR', 'value': 250, 'inequality': '>'},
                            {'depth1': 2600, 'depth2': 2700, 'well': '17/4-1', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 1800, 'depth2': 2000, 'well': '25/10-4 R', 'curve': 'DRHO', 'value': 0, 'inequality': '<'},
                            {'depth1': 3400, 'depth2': 3500, 'well': '25/2-13 T4', 'curve': 'RHOB', 'value': 1.8, 'inequality': '<'},
                            {'depth1': 3022.6790771, 'depth2': 3500, 'well': '25/2-14', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 3300, 'depth2': 3600, 'well': '25/2-14', 'curve': 'DRHO', 'value': 0.25, 'inequality': '>'},
                            {'depth1': 3200, 'depth2': 3300, 'well': '25/6-1', 'curve': 'GR', 'value': 270, 'inequality': '>'},
                            {'depth1': 3190, 'depth2': 3300, 'well': '25/6-1', 'curve': 'DRHO', 'value': 0.25, 'inequality': '>'},
                            {'depth1': 1200, 'depth2': 2200, 'well': '25/8-5 S', 'curve': 'NPHI', 'value': 0.99, 'inequality': '>'},
                            {'depth1': 2500, 'depth2': 3500, 'well': '26/4-1', 'curve': 'CALI', 'value': 15, 'inequality': '>'},
                            {'depth1': 1500, 'depth2': 2500, 'well': '30/11-3', 'curve': 'CALI', 'value': 11, 'inequality': '<'},
                            {'depth1': 3000, 'depth2': 3500, 'well': '30/2-1', 'curve': 'SP', 'value': 140, 'inequality': '<'},
                            {'depth1': 4400, 'depth2': 4750, 'well': '30/4-2', 'curve': 'CALI', 'value': 4, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 3250, 'well': '30/6-11', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 3250, 'well': '30/6-11', 'curve': 'NPHI', 'value': 0.5, 'inequality': '>'},
                            {'depth1': 2500, 'depth2': 3250, 'well': '30/6-11', 'curve': 'DRHO', 'value': 0.2, 'inequality': '>'},
                            {'depth1': 2500, 'depth2': 3250, 'well': '30/6-11', 'curve': 'DRHO', 'value': -0.15, 'inequality': '<'},
                            {'depth1': 2000, 'depth2': 2500, 'well': '30/6-8', 'curve': 'DRHO', 'value': 0.21, 'inequality': '>'},
                            {'depth1': 1000, 'depth2': 1500, 'well': '30/6-8', 'curve': 'DRHO', 'value': -0.1, 'inequality': '<'},
                            {'depth1': 4800, 'depth2': 5000, 'well': '30/7-7', 'curve': 'DRHO', 'value': -0.25, 'inequality': '<'},
                            {'depth1': 4800, 'depth2': 5000, 'well': '30/7-7', 'curve': 'RHOB', 'value': 3, 'inequality': '>'},
                            {'depth1': 4400, 'depth2': 4800, 'well': '30/7-7', 'curve': 'CALI', 'value': 5, 'inequality': '<'},
                            {'depth1': 2200, 'depth2': 2400, 'well': '31/2-1', 'curve': 'RHOB', 'value': 1.5, 'inequality': '<'},
                            {'depth1': 2250, 'depth2': 2500, 'well': '31/2-3', 'curve': 'GR', 'value': 250, 'inequality': '>'},
                            {'depth1': 1500, 'depth2': 2000, 'well': '31/2-8', 'curve': 'GR', 'value': 180, 'inequality': '>'},
                            {'depth1': 1800, 'depth2': 2200, 'well': '31/4-2', 'curve': 'CALI', 'value': 10, 'inequality': '<'},
                            {'depth1': 2000, 'depth2': 4500, 'well': '31/4-3', 'curve': 'NPHI', 'value': 0.99, 'inequality': '>'},
                            {'depth1': 2200, 'depth2': 2400, 'well': '31/4-4', 'curve': 'NPHI', 'value': 0.9, 'inequality': '>'},
                            {'depth1': 2200, 'depth2': 2400, 'well': '31/4-4', 'curve': 'GR', 'value': 250, 'inequality': '>'},
                            {'depth1': 3000, 'depth2': 3600, 'well': '31/6-1', 'curve': 'GR', 'value': 150, 'inequality': '>'},
                            {'depth1': 3000, 'depth2': 3600, 'well': '31/6-1', 'curve': 'DRHO', 'value': 0.3, 'inequality': '>'},
                            {'depth1': 2800, 'depth2': 2900, 'well': '33/9-6', 'curve': 'CALI', 'value': 13, 'inequality': '<'},
                            {'depth1': 1000, 'depth2': 1900, 'well': '34/10-12', 'curve': 'CALI', 'value': 11, 'inequality': '<'},
                            {'depth1': 3500, 'depth2': 3750, 'well': '34/10-16 R', 'curve': 'DRHO', 'value': -0.05, 'inequality': '<'},
                            {'depth1': 3000, 'depth2': 3250, 'well': '34/10-21', 'curve': 'DRHO', 'value': -0.05, 'inequality': '<'},
                            {'depth1': 3000, 'depth2': 3250, 'well': '34/10-21', 'curve': 'RHOB', 'value': 3, 'inequality': '>'},
                            {'depth1': 1800, 'depth2': 1900, 'well': '34/10-7', 'curve': 'NPHI', 'value': 0.9, 'inequality': '>'},
                            {'depth1': 3000, 'depth2': 3250, 'well': '34/2-2 R', 'curve': 'SP', 'value': 20, 'inequality': '<'},
                            {'depth1': 3700, 'depth2': 3900, 'well': '34/2-4', 'curve': 'RHOB', 'value': 3, 'inequality': '>'},
                            {'depth1': 3400, 'depth2': 3500, 'well': '34/4-2', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 2000, 'depth2': 2500, 'well': '34/4-3', 'curve': 'NPHI', 'value': 0.25, 'inequality': '<'},
                            {'depth1': 2000, 'depth2': 2500, 'well': '34/4-3', 'curve': 'CALI', 'value': 12, 'inequality': '<'},
                            {'depth1': 2500, 'depth2': 3000, 'well': '34/4-3', 'curve': 'GR', 'value': 100, 'inequality': '>'},
                            {'depth1': 2000, 'depth2': 2500, 'well': '34/4-3', 'curve': 'SP', 'value': 70, 'inequality': '<'},
                            {'depth1': 2800, 'depth2': 3000, 'well': '34/7-5', 'curve': 'CALI', 'value': 10, 'inequality': '<'},
                            {'depth1': 3000, 'depth2': 3250, 'well': '34/8-1', 'curve': 'CALI', 'value': 8, 'inequality': '<'},
                            {'depth1': 4200, 'depth2': 4800, 'well': '34/8-7', 'curve': 'CALI', 'value': 9, 'inequality': '<'},
                            {'depth1': 4800, 'depth2': 5200, 'well': '34/8-7', 'curve': 'DRHO', 'value': 0.1, 'inequality': '>'},
                            {'depth1': 2014.0010376, 'depth2': 3356.0010376, 'well': '35/11-1', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 3400, 'depth2': 3600, 'well': '35/11-5', 'curve': 'DRHO', 'value': 0.05, 'inequality': '>'},
                            {'depth1': 1772.625, 'depth2': 2880.625, 'well': '35/11-7', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 3500, 'depth2': 4000, 'well': '35/3-5', 'curve': 'GR', 'value': 190, 'inequality': '>'},
                            {'depth1': 1500, 'depth2': 2000, 'well': '35/8-1', 'curve': 'CALI', 'value': 15, 'inequality': '<'},
                            {'depth1': 1500, 'depth2': 2000, 'well': '35/8-1', 'curve': 'RHOB', 'value': 1.5, 'inequality': '<'},
                            {'depth1': 1000, 'depth2': 1500, 'well': '35/8-1', 'curve': 'RHOB', 'value': 2.5, 'inequality': '>'},
                            {'depth1': 1000, 'depth2': 1500, 'well': '35/8-1', 'curve': 'DRHO', 'value': 0.2, 'inequality': '>'},
                            {'depth1': 1300, 'depth2': 1500, 'well': '36/7-1', 'curve': 'CALI', 'value': 11, 'inequality': '<'},
                            {'depth1': 2750, 'depth2': 3250, 'well': '6/3-2', 'curve': 'GR', 'value': 200, 'inequality': '>'},
                            {'depth1': 2250, 'depth2': 2500, 'well': '6/3-2', 'curve': 'RHOB', 'value': 2.8, 'inequality': '>'},
                            {'depth1': 2000, 'depth2': 2500, 'well': '6/3-2', 'curve': 'DRHO', 'value': 0.4, 'inequality': '>'},
                            {'depth1': 2500, 'depth2': 2750, 'well': '6/3-2', 'curve': 'NPHI', 'value': 0.5, 'inequality': '>'},
                            {'depth1': 1400, 'depth2': 2000, 'well': '6/3-2', 'curve': 'NPHI', 'value': 0.6, 'inequality': '>'},
                            {'depth1': 2500, 'depth2': 2750, 'well': '6/3-2', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 2750, 'depth2': 3010, 'well': '15/9-9', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'},
                            {'depth1': 2200, 'depth2': 2800, 'well': '31/4-4', 'curve': 'NPHI', 'value': 0.002, 'inequality': '<'}
]

# %%
for params in corrections_outlier_list:
    correction_outlier(df_depth_filtered, **params)

# %%
df_depth_filtered = df_depth_filtered.groupby(level=0).apply(interpolate_nan_values).droplevel(0)

# %%
import welly.quality as wq

tests = {'GR': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_positive],
         'RHOB': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_positive],
         'NPHI': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_between(0,1)],
         'DRHO': [wq.no_flat,
                  wq.no_gaps],
         'CALI': [wq.no_flat,
                  wq.no_gaps,
                  wq.all_positive],
         'SP': [wq.no_flat,
                  wq.no_gaps],
         }

# %%
for well in df_depth_filtered.index.get_level_values(0).unique():
  w = df_depth_filtered.loc[well]
  wl = welly.Well({})
  for log in tests.keys():  # Проходим по логам, для которых есть тесты
        if log in w.columns:  # Проверяем, имеются ли данные по этому логe
            wl.data[log] = welly.Curve(w[log].values, basis=w.index.get_level_values('DEPT').values, mnemonic=log)

 # show test results in HTML table
  print('\n', '\n')
  print('WELL NAME: ' + well)
  print('CURVE QUALITY SUMMARY')
  html = wl.qc_table_html(tests)
  display(HTML(html, metadata = {'title': well,}))
# Out:
#
#
# WELL NAME: 15/9-12
# CURVE QUALITY SUMMARY
# <ipython-input-39-07f5de20f79b>:6: DeprecationWarning: In a future release, the basis argument will be removed; use index instead.
#   wl.data[log] = welly.Curve(w[log].values, basis=w.index.get_level_values('DEPT').values, mnemonic=log)
# ...

# %%
df_plot = df_depth_filtered.copy()
df_plot.reset_index(inplace=True)

# %%
def create_plot(wellname, dataframe,
                curves_to_plot, depth_curve,
                log_curves=[]):

    # Count the number of tracks we need
    num_tracks = len(curves_to_plot)

    # Setup the figure and axes
    fig, ax = plt.subplots(nrows=1, ncols=num_tracks, figsize=(num_tracks*2, 10))

    # Create a super title for the entire plot
    fig.suptitle(wellname, fontsize=20, y=1.05)

    # Loop through each curve in curves_to_plot and create a track with that data
    for i, curve in enumerate(curves_to_plot):


        ax[i].plot(dataframe[curve], depth_curve)

        # Setup a few plot cosmetics
        ax[i].set_title(curve, fontsize=14, fontweight='bold')
        ax[i].grid(which='major', color='lightgrey', linestyle='-')

        # We want to pass in the deepest depth first, so we are displaying the data
        # from shallow to deep
        ax[i].set_ylim(depth_curve.max(), depth_curve.min())

        # Only set the y-label for the first track. Hide it for the rest
        if i == 0:
            ax[i].set_ylabel('DEPTH (m)', fontsize=18, fontweight='bold')
        else:
            plt.setp(ax[i].get_yticklabels(), visible = False)

        # Check to see if we have any logarithmic scaled curves
        if curve in log_curves:
            ax[i].set_xscale('log')
            ax[i].grid(which='minor', color='lightgrey', linestyle='-')

    plt.tight_layout()
    plt.show()

# %%
grouped = df_plot.groupby('UWI')
dfs_wells = []
wellnames = []

for well, data in grouped:
  dfs_wells.append(data)
  wellnames.append(well)
curves_to_plot = ['CALI', 'RHOB', 'DRHO', 'GR', 'NPHI', 'SP']

# %%
for well in range(len(wellnames)):
  create_plot(wellnames[well], dfs_wells[well],
              curves_to_plot, dfs_wells[well]['DEPT'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df_depth_filtered.to_csv('force_logs.csv', index = True)
